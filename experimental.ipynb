# %%
import pandas as pd

# %%
use_cols = ['LOAN_ID', 'RECEIVED_D', 'MONTHLYPAYMENT_INVESTORS']
df = pd.read_csv('data/PMTHIST_INVESTOR_201808.csv', nrows=100)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 40 columns):
# LOAN_ID                         100 non-null int64
# RECEIVED_D                      100 non-null object
# PERIOD_END_LSTAT                100 non-null object
# Month                           100 non-null object
# MOB                             100 non-null int64
# CO                              100 non-null int64
# PBAL_BEG_PERIOD_INVESTORS       100 non-null float64
# PRNCP_PAID_INVESTORS            100 non-null float64
# INT_PAID_INVESTORS              100 non-null float64
# FEE_PAID_INVESTORS              100 non-null int64
# DUE_AMT_INVESTORS               100 non-null float64
# RECEIVED_AMT_INVESTORS          100 non-null float64
# PBAL_END_PERIOD_INVESTORS       100 non-null float64
# MONTHLYPAYMENT_INVESTORS        100 non-null float64
# COAMT_INVESTORS                 100 non-null int64
# InterestRate                    100 non-null float64
# ...

# %%
df[['IssuedDate', 'RECEIVED_D', 'PBAL_END_PERIOD_INVESTORS']]
# Out:
#    IssuedDate RECEIVED_D  PBAL_END_PERIOD_INVESTORS
# 0     AUG2009    SEP2009               18636.409300
# 1     AUG2009    OCT2009               18188.363925
# 2     AUG2009    NOV2009               17735.877487
# 3     AUG2009    DEC2009               17278.905966
# 4     AUG2009    JAN2010               16817.404904
# 5     AUG2009    FEB2010               16351.329406
# 6     AUG2009    MAR2010               15880.634129
# 7     AUG2009    APR2010               15405.273281
# 8     AUG2009    MAY2010               14925.200617
# 9     AUG2009    JUN2010               14440.369432
# 10    AUG2009    JUL2010               13950.732560
# 11    AUG2009    AUG2010               13456.242367
# 12    AUG2009    SEP2010               12956.850745
# 13    AUG2009    OCT2010               12452.509113
# 14    AUG2009    NOV2010               11943.168404
# 15    AUG2009    DEC2010               11428.779067
# 16    AUG2009    JAN2011               10909.291061
# ...

# %%
df['MONTHLYPAYMENT_INVESTORS'] = df['MONTHLYPAYMENT_INVESTORS'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
# LOAN_ID                     100 non-null int64
# Month                       100 non-null object
# MONTHLYPAYMENT_INVESTORS    100 non-null float32
# dtypes: float32(1), int64(1), object(1)
# memory usage: 2.0+ KB

# %%
df.head()
# Out:
#    LOAN_ID    Month  MONTHLYPAYMENT_INVESTORS
# 0    54734  SEP2009                632.770996
# 1    54734  OCT2009                632.770996
# 2    54734  NOV2009                632.770996
# 3    54734  DEC2009                632.770996
# 4    54734  JAN2010                632.770996

# %%
class Loan:
    def __init__(self, loan_id, amount, principal_remaining):
            self.id = loan_id
            self.principal_remaining = principal_remaining
